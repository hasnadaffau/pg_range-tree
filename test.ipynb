# %%
pip install matplotlib graphviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 22.0.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/usr/local/bin/python3.9 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from src.node import create_node
from src.range_tree import build_2d_range_tree, range_query
from src.visual import plot_points, visualize_tree_radial
import random

# %%
points = [(random.randint(1, 30), random.randint(1, 30)) for _ in range(20)]
# points = [(2,3), (4,7), (5,4), (7,2), (8,5)]
# points = [
#     (2, 3), (4, 2), (7, 1), (8, 5), (9, 6), (10, 4),
#     (1, 8), (3, 7), (5, 9), (6, 2), (12, 8), (14, 3),
#     (15, 5), (11, 7), (13, 9), (16, 4), (17, 10), (18, 2),
#     (19, 6), (20, 8), (21, 1), (22, 5), (23, 7), (24, 9),
#     (25, 3), (26, 11), (27, 2), (28, 8), (29, 4), (30, 6),
#     (31, 12), (32, 1), (33, 5), (34, 7), (35, 3), (36, 9),
#     (37, 2), (38, 10), (39, 6), (40, 8)
# ]


tree = build_2d_range_tree(points)
x_range =(10,20)
y_range =(15,30)

# %%
result = range_query(tree, x_range,y_range)
print("Query result:", result)
# Out:
# Query result: [(14, 30), (20, 30), (20, 16), (11, 25), (17, 18)]

# %%
plot_points(points, result, x_range, y_range)

# %%
graph = visualize_tree_radial(tree)

# %%
graph.render("/tmp/range_tree", view=False)
graph

# %%
graph.render('range_tree_graph', format='png', cleanup=True)
# Out:
# 'range_tree_graph.png'
